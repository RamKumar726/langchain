# %% [markdown]
# ### Langchain

# %% [markdown]
# ## Agents

# %%
# %pip install langchain-google-vertexai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-google-vertexai
#   Using cached langchain_google_vertexai-3.2.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: bottleneck<2.0.0,>=1.4.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (1.6.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.97.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (1.165.1)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (3.13.1)
# Requirement already satisfied: google-cloud-vectorsearch>=0.2.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (0.11.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (0.28.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (1.6.0)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.6 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (2.14.2)
# Requirement already satisfied: pyarrow<24.0.0,>=19.0.1 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (23.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (2.13.4)
# Requirement already satisfied: validators<1.0.0,>=0.22.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-google-vertexai) (0.35.0)
# Requirement already satisfied: numpy in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from bottleneck<2.0.0,>=1.4.0->langchain-google-vertexai) (2.5.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.34.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.55.2)
# Requirement already satisfied: certifi>=2023.7.22 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2026.6.17)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.28.4)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (26.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.44.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.18.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.66.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.12.1)
# Requirement already satisfied: typing_extensions in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (4.16.0)
# Requirement already satisfied: docstring_parser<1 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.69.2 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.34.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.59.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.83.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.59.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.83.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (49.0.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.7.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.14.5)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.6.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-cloud-storage<4.0.0,>=2.18.0->langchain-google-vertexai) (1.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (4.14.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (16.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.66.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.18)
# Requirement already satisfied: httpcore==1.* in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.28.0->langchain-google-vertexai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.0->langchain-google-vertexai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (0.11.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-vertexai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.9.0->langchain-google-vertexai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.9.0->langchain-google-vertexai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.9.0->langchain-google-vertexai) (0.4.2)
# Requirement already satisfied: six>=1.5 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.1.0)
# Requirement already satisfied: pycparser in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\ramku\AppData\Roaming\Python\Python314\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.6.4)
# Using cached langchain_google_vertexai-3.2.4-py3-none-any.whl (118 kB)
# Installing collected packages: langchain-google-vertexai
# Successfully installed langchain-google-vertexai-3.2.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import langchain
langchain.__version__
# Out:
# '1.3.17'

# %%
from langchain.agents import create_agent
from dotenv import load_dotenv

load_dotenv()

agent = create_agent(
    model= "google_genai:gemini-2.5-flash",
    tools=[],
    system_prompt=" You are an helpful assistant."
)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\google\cloud\aiplatform\initializer.py:363, in _Config.project(self)
#     362 try:
# --> 363     self._set_project_as_env_var_or_google_auth_default()
#     364     project_id = self._project
#
# File ~\AppData\Roaming\Python\Python314\site-packages\google\cloud\aiplatform\initializer.py:114, in _Config._set_project_as_env_var_or_google_auth_default(self)
#     113 else:
# --> 114     credentials, project = google.auth.default()
#     115     self._credentials = self._credentials or credentials
#
# File ~\AppData\Roaming\Python\Python314\site-packages\google\auth\_default.py:748, in default(scopes, request, quota_project_id, default_scopes)
#     746         return credentials, effective_project_id
# --> 748 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# Cell In[9], line 6
#       2 from dotenv import load_dotenv
#       3
#       4 load_dotenv()
#       5
# ----> 6 agent = create_agent(
#       7     model= "gemini-2.5-flash",
#       8     tools=[],
#       9     system_prompt=" You are an helpful assistant."
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain\agents\factory.py:996, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache, transformers)
#     994 # init chat model
#     995 if isinstance(model, str):
# --> 996     model = init_chat_model(model)
#     998 # Convert system_prompt to SystemMessage if needed
#     999 system_message: SystemMessage | None = None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain\chat_models\base.py:516, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     508     warnings.warn(
#     509         f"{config_prefix=} has been set but no fields are configurable. Set "
#     510         f"`configurable_fields=(...)` to specify the model params that are "
#     511         f"configurable.",
#     512         stacklevel=2,
#     513     )
#     515 if not configurable_fields:
# --> 516     return _init_chat_model_helper(
#     517         cast("str", model),
#     518         model_provider=model_provider,
#     519         **kwargs,
#     520     )
#     521 if model:
#     522     kwargs["model"] = model
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain\chat_models\base.py:540, in _init_chat_model_helper(model, model_provider, **kwargs)
#     538 model, model_provider = _parse_model(model, model_provider)
#     539 creator_func = _get_chat_model_creator(model_provider)
# --> 540 return creator_func(model=model, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain\chat_models\base.py:53, in _call(cls, **kwargs)
#      51 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      52     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 53     return cls(**kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_core\_api\deprecation.py:274, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     271     # Only mark the warning as emitted if it was not intentionally
#     272     # suppressed by `suppress_langchain_deprecation_warning()`.
#     273     warned = not _SUPPRESSING_LANGCHAIN_DEPRECATION_WARNING.get()
# --> 274 return wrapped(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_google_vertexai\chat_models.py:1943, in ChatVertexAI.__init__(self, model_name, **kwargs)
#    1937         suggestion = (
#    1938             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1939         )
#    1940         logger.warning(
#    1941             f"Unexpected argument '{arg}' provided to ChatVertexAI.{suggestion}"
#    1942         )
# -> 1943 super().__init__(**kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_google_vertexai\_base.py:156, in _VertexAIBase.validate_project(self)
#     154         self.project = self.credentials.project_id
#     155     else:
# --> 156         self.project = initializer.global_config.project
#     157 return self
#
# File ~\AppData\Roaming\Python\Python314\site-packages\google\cloud\aiplatform\initializer.py:366, in _Config.project(self)
#     364     project_id = self._project
#     365 except GoogleAuthError as exc:
# --> 366     raise GoogleAuthError(project_not_found_exception_str) from exc
#     368 if not project_id and not self.api_key:
#     369     raise ValueError(project_not_found_exception_str)
#
# GoogleAuthError: Unable to find your project. Please provide a project ID by:
# - Passing a constructor argument
# - Using vertexai.init()
# - Setting project using 'gcloud config set project my-project'
# - Setting a GCP environment variable
# - To create a Google Cloud project, please follow guidance at https://developers.google.com/workspace/guides/create-project
